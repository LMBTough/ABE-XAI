# %%
from trulens_eval import Visualizer, get_backend
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from trulens_eval import Visualizer, get_backend
#
# File ~/miniconda3/lib/python3.12/site-packages/trulens_eval/__init__.py:8
#       1 # ruff: noqa: E402
#       2 """
#       3 !!! warning
#       4     This module is deprecated and will be removed. Use `trulens.core`,
#       5     `trulens.feedback`, `trulens.dashboard` instead.
#       6 """
# ----> 8 from trulens.core._utils import optional as optional_utils
#       9 from trulens.core.utils import deprecation as deprecation_utils
#      10 from trulens.core.utils import imports as import_utils
#
# File ~/miniconda3/lib/python3.12/site-packages/trulens/core/__init__.py:8
#       5 from importlib.metadata import version
#       6 import os
# ----> 8 from trulens.core.feedback.feedback import Feedback
# ...

# %%
from trulens_eval.nn.models import get_model_wrapper
wrapped_model = get_model_wrapper(model_defined_via_keras)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from trulens_eval.nn.models import get_model_wrapper
#       2 wrapped_model = get_model_wrapper(model_defined_via_keras)
#
# File ~/miniconda3/lib/python3.12/site-packages/trulens_eval/__init__.py:8
#       1 # ruff: noqa: E402
#       2 """
#       3 !!! warning
#       4     This module is deprecated and will be removed. Use `trulens.core`,
#       5     `trulens.feedback`, `trulens.dashboard` instead.
#       6 """
# ----> 8 from trulens.core._utils import optional as optional_utils
#       9 from trulens.core.utils import deprecation as deprecation_utils
#      10 from trulens.core.utils import imports as import_utils
#
# File ~/miniconda3/lib/python3.12/site-packages/trulens/core/__init__.py:8
#       5 from importlib.metadata import version
#       6 import os
# ...
